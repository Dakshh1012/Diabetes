# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv(r"C:\Users\Daksh\Desktop\diabetes.csv")

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
def preprocessing(data):
    data=data.copy()
    Y=data["Outcome"]
    X=data.drop(columns="Outcome",axis=1)
    feature_names=X.columns
    X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)
    return X_train,X_test,Y_train,Y_test,feature_names

# %%
X_train,X_test,Y_train,Y_test,feature_name=preprocessing(data)

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)
import warnings
from sklearn.exceptions import DataConversionWarning

warnings.filterwarnings("ignore", category=UserWarning)

# %%
classifier=svm.SVC(kernel="linear")

# %%
classifier.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
X_test_prediction=classifier.predict(X_test)
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)

# %%
test_data_accuracy
# Out:
# 0.7662337662337663

# %%
plt.plot(X_test,Y_test)

# %%
output = []
for feature in feature_name:
    output.append(int(input(f"Enter the value of {feature}: ")))
output_array = np.array(output)
output_array = output_array.reshape(1, -1)
# Out:
# Enter the value of Pregnancies:  1
# Enter the value of Glucose:  1
# Enter the value of BloodPressure:  1
# Enter the value of SkinThickness:  1
# Enter the value of Insulin:  1
# Enter the value of BMI:  1
# Enter the value of DiabetesPedigreeFunction:  1
# Enter the value of Age:  1

# %%
prediction = classifier.predict(output_array)
prediction
# Out:
# array([1], dtype=int64)

# %%
if(prediction[0]==1):
    print("diabetic")
else:
    print("non diabetic ;)")
# Out:
# diabetic
